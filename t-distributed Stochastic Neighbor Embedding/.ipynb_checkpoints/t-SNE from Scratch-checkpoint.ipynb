# %% [markdown]
# # Implementing t-SNE using NUMPY

# %% [markdown]
# ## Dependencies

# %%
# !pip install scikit-learn matplotlib
# !pip install scipy
# Out:
# Requirement already satisfied: scikit-learn in c:\users\dravi\appdata\local\programs\python\python311\lib\site-packages (1.5.2)
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: matplotlib in c:\users\dravi\appdata\local\programs\python\python311\lib\site-packages (3.9.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\dravi\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\dravi\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dravi\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dravi\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dravi\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dravi\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dravi\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dravi\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\dravi\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\dravi\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dravi\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dravi\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\dravi\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: scipy in c:\users\dravi\appdata\local\programs\python\python311\lib\site-packages (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in c:\users\dravi\appdata\local\programs\python\python311\lib\site-packages (from scipy) (2.0.2)
# WARNING: There was an error checking the latest version of pip.

# %%
from sklearn.datasets import fetch_openml
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading the Dataset

# %%
# MNIST dataset
mnist = fetch_openml('mnist_784', version=1)
X, y = mnist["data"], mnist["target"].astype(int)

# Using only a subset of the dataset to help compute faster
X = X[:5000]
y = y[:5000]

# Normalize the data
X = X / 255.0  # Greyscale 0 - 255

# %% [markdown]
# ## Pre-existing Methodologies

# %% [markdown]
# ### t-SNE using scikit-learn

# %%
tsne = TSNE(n_components=2, random_state=42, perplexity=30, max_iter=300)
X_embedded = tsne.fit_transform(X)

# Visualizing
plt.figure(figsize=(10, 8))
plt.scatter(X_embedded[:, 0], X_embedded[:, 1], c=y, cmap='jet', s=10)
plt.colorbar()
plt.title('t-SNE Visualization of MNIST Dataset')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.show()

# %% [markdown]
# ### Applying t-SNE in 3D

# %%
from mpl_toolkits.mplot3d import Axes3D

# Apply t-SNE with n_components=3
tsne_3d = TSNE(n_components=3, random_state=42, perplexity=30, max_iter=300)
X_embedded_3d = tsne_3d.fit_transform(X)


# Visualization
# Plot in 3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(X_embedded_3d[:, 0], X_embedded_3d[:, 1], X_embedded_3d[:, 2], c=y, cmap='jet', s=10)
plt.colorbar(scatter)
ax.set_title('3D t-SNE Visualization of MNIST Dataset')
ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
ax.set_zlabel('Component 3')
plt.show()
# Out:
# C:\Users\dravi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\manifold\_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %% [markdown]
# ## Implementing t-SNE using NUMPY
#
# references : <br> https://www.dailydoseofds.com/formulating-and-implementing-the-t-sne-algorithm-from-scratch/ <br>
# https://www.geeksforgeeks.org/students-t-distribution-in-statistics/

# %%
from scipy.spatial.distance import pdist, squareform

# %% [markdown]
# ### Step - 1 Pairwise Affinities (PD) in High-Dimensional Space

# %% [markdown]
# 1. Pairwise Squared Euclidean Distance <br>
# ![image.png](attachment:20ec60a9-9702-4a8f-a2e6-3aa06205ab5c.png)
#
# 2. Gaussian Kernel <br>
# ![image.png](attachment:e7b9ea34-e751-4f0e-ad2c-3c7269e35d6c.png)
#
# 3. Symmetrize Probabilities <br>
# ![image.png](attachment:d75beb88-99f0-4615-9227-76733b2fcaaa.png)

# %%
def compute_pairwise_affinities(X, perplexity=30):
    """
    Compute pairwise affinities (P_{j|i}) using a Gaussian kernel.
    """
    n = X.shape[0]
    distances = squareform(pdist(X, 'sqeuclidean'))  # Pairwise squared Euclidean distances
    affinities = np.zeros((n, n))

    for i in range(n):
        beta = binary_search_beta(distances[i], perplexity)
        affinities[i] = np.exp(-beta * distances[i])
        affinities[i, i] = 0  # Set diagonal to 0 as P(i,i) is pointless. A point can't be a neighbour to itself

    # Normalize to get probabilities
    affinities /= np.sum(affinities, axis=1, keepdims=True)
    return affinities

# %% [markdown]
# ### Step - 2 Binary Search for Optimal Variance

# %% [markdown]
# 1. Perplexity <br>
# ![image.png](attachment:df07e27c-5018-4ad4-b345-2824e1897503.png)
#
#     $H(P_i)$ is the Shannon entropy of $P_i$ <br>
#     ![image.png](attachment:1b3e8fae-47b7-4caf-b2f1-a578e2a90de7.png)
#
# 2. Binary Search <br>
#     Adjust $σ_i$ until perplexity matches the desired value

# %%
def binary_search_beta(distances, perplexity, tol=1e-5, max_iter=50):
    """
    Perform binary search to find the optimal beta (precision) for a given perplexity.
    """
    n = len(distances)
    beta = 1.0  # Initialize beta
    beta_min, beta_max = -np.inf, np.inf  # Initialize bounds
    target_entropy = np.log(perplexity)

    for _ in range(max_iter):
        # Compute probabilities
        probs = np.exp(-distances * beta)
        probs /= np.sum(probs) + 1e-10  # Avoid division by zero

        # Compute Shannon entropy
        entropy = -np.sum(probs * np.log2(np.maximum(probs, 1e-10)))  # Avoid log(0)

        # Check for convergence
        if np.abs(entropy - target_entropy) < tol:
            break

        # Adjust beta
        if entropy > target_entropy:
            beta_min = beta
            beta = beta * 2 if beta_max == np.inf else (beta + beta_max) / 2
        else:
            beta_max = beta
            beta = beta / 2 if beta_min == -np.inf else (beta + beta_min) / 2

    return beta

# %% [markdown]
# ### Step 3 Compute Pairwise Affinities in Low-Dimensional Space and Gradient of KL Divergence
# In low-d space, we compute the probability of $Q_ij$ that point $y_i$ would pick $y_j$ as its neighbour using a heavy-tailed distribution(Student-t), this helps prevent crowding in low-dimensional space. <br>
# The goal is to minimize the KL Divergence between the high-dimensional $(P_ij)$ and low-dimensikonal $(Q_ij)$ distributions.

# %% [markdown]
# 1. Pairwise Squared Euclidean Distance (using the function defined above) <br>
# 2. Student-t Kernal <br>
# ![image.png](attachment:3b7b67d2-66c0-470b-954b-23145f828373.png)
#
# 3. Gradient of KL Divergence <br>
# ![image.png](attachment:3b4ab3ca-a3a1-4034-b606-e3ed24fe7247.png)

# %%
def tsne(X, n_components=2, perplexity=30, n_iter=300, learning_rate=200):
    """
    Perform t-SNE dimensionality reduction.
    """
    n = X.shape[0]
    Y = np.random.randn(n, n_components)  # Random initialization of low-dimensional embedding
    P = compute_pairwise_affinities(X, perplexity)
    P = (P + P.T) / (2 * n)  # Symmetrize and normalize

    for iter in range(n_iter):
        # Compute pairwise affinities in low-dimensional space (Q_{ij})
        distances = squareform(pdist(Y, 'sqeuclidean'))
        Q = 1 / (1 + distances)
        np.fill_diagonal(Q, 0)
        Q /= np.sum(Q) + 1e-10  # Avoid division by zero

        # Compute gradient of KL divergence
        grad = np.zeros_like(Y)
        for i in range(n):
            diff = Y[i] - Y
            grad[i] = 4 * np.sum((P[i] - Q[i])[:, np.newaxis] * Q[i][:, np.newaxis] * diff, axis=0)

        # Update embedding
        Y -= learning_rate * grad

        # Visualize intermediate results
        if iter % 50 == 0 and y is not None:
            plt.scatter(Y[:, 0], Y[:, 1], c=y, cmap='jet', s=10)
            plt.title(f't-SNE Iteration {iter}')
            plt.show()

    return Y

# %% [markdown]
# ## Application

# %%
# I am reducing the dataset to 1000 digits as I have increased the iterations to a large amount
X = X[:1000]
y = y[:1000]

# Apply t-SNE
Y = tsne(X, n_components=2, perplexity=30, n_iter=300, learning_rate=200)

# Final visualization
plt.scatter(Y[:, 0], Y[:, 1], c=y, cmap='jet', s=10)
plt.title('t-SNE Visualization of MNIST Dataset')
plt.show()

# %% [markdown]
# It's evident that there are no distinct clusters

# %% [markdown]
# ### Experimenting with a differnt set of params

# %%
Y = tsne(X, n_components=2, perplexity=40, n_iter=1000, learning_rate=100)

# Final Plot
plt.figure(figsize=(8,6))
plt.scatter(Y[:, 0], Y[:, 1], c=y, cmap='jet', s=10, alpha=0.7)
plt.colorbar()
plt.title("t-SNE Visualization of MNIST Dataset")
plt.show()
